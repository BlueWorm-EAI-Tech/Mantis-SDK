# %%
import sys
import threading
from mantis import Mantis
import time
import sys
import threading
from mantis import Mantis
import time
print("=== Mantis 全关节方向测试 ===\n")

robot = Mantis(ip="192.168.1.204")
if not robot.connect(verify=True):
    sys.exit(1) 
robot.home()
# Out:
# === Mantis 全关节方向测试 ===
#
# ⏳ 正在连接 Mantis 机器人 (tcp/192.168.1.204:7447)...
# ✅ 已连接到 Mantis 机器人

# %%
# robot.left_arm.ik(0.0, 1.0, 1.0, 0, 0, 0)
robot.home()

# %%
robot.left_arm.ik(0.0, 0.0, 0.1, 0, 0, 0, abs=False)

# %%
robot.left_arm.ik(0.5, 0.5, 0.5, 0, 0, 0)

# %%
robot.left_arm.set_shoulder_pitch(1, block=False)
