# %%
import sys
import threading
from mantis import Mantis
import time
print("=== Mantis 全关节方向测试 ===\n")

robot = Mantis(ip="192.168.1.151")
if not robot.connect(verify=False):
    sys.exit(1)
# Out:
# === Mantis 全关节方向测试 ===
#
# ⏳ 正在连接 Mantis 机器人 (tcp/192.168.1.151:7447)...
# ✅ 已连接到 Mantis 机器人

# %%
robot.left_arm.home()

# %%
robot.left_arm.ik(0,0.1,0,0,0,0,abs=False)
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************

# %%
robot.left_arm.ik(-0.3,0.5,0.7,0,0,0,abs=True)
robot.left_gripper.open()
